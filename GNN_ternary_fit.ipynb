# %% [markdown]
# ### Imports

# %%
import time
import pickle
import numpy as np
import pandas as pd

from tabulate import tabulate
from collections import Counter

from pprint import pprint as pp
import matplotlib.pyplot as plt

from IPython.display import clear_output

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc, confusion_matrix, ConfusionMatrixDisplay

import torch
print(f'PyTorch version: {torch.__version__}, CUDA version: {torch.version.cuda}')

from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
import torch.nn as nn
from torch_scatter import scatter_add
import torch.nn.functional as F

# Get rid of RuntimeWarnings, gross
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
# Out:
# PyTorch version: 2.1.0+cu121, CUDA version: 12.1

# %% [markdown]
# ### Data preparation

# %%
# events_file_path = '/storage/MUonE/milosz/events2D_3stat_1.pickle'
events_file_path = '/storage/MUonE/mwolter/events2D_NormalSample_3.pickle'

# %% [markdown]
# #### Constants

# %%
z_scale = 100.

x_layers = [18.0, 89.5, 118.0, 189.5, 218.0, 289.5]      # z-coordinates of layers measuring x
y_layers = [21.0, 93.0, 122.0, 194.0, 222.0, 294.0]      # z-coordinates of layers measuring y
stereo_layers = [55.4, 56.7, 155.4, 156.7, 255.4, 256.7] # z-coordinates of layers measuring u or v

all_layers = sorted(x_layers + y_layers + stereo_layers)

# %% [markdown]
# #### Data load

# %%
# Function to get number of layer based on z-coordinate
def z_to_layer(z):
    differences = [abs(z - layer) for layer in all_layers]
    closest_index = differences.index(min(differences))
    return closest_index


# Function to get type of layer based on z-coordinate
def layer_type(z):
    layers = [(layer, 'x') for layer in x_layers] + \
             [(layer, 'y') for layer in y_layers] + \
             [(layer, 'stereo') for layer in stereo_layers]

    closest_layer = min(layers, key=lambda x: abs(x[0] - z))
    
    return closest_layer[1]


# Function to calculate chi-square of fit to filter out broken events
def check_ch2(event):
    zx_mu, zx_e, x_mu, x_e, zy_mu, zy_e, y_mu, y_e = [], [], [], [], [], [], [], []
    
    for hit in event:
        if layer_type(hit[0]) == 'x' and hit[0] < 300:
            if hit[2] in [0,1]:
                zx_mu.append(hit[0])
                x_mu.append(hit[1])
            else:
                zx_e.append(hit[0])
                x_e.append(hit[1])
                
        if layer_type(hit[0]) == 'y' and hit[0] < 300:
            if hit[2] in [0,1]:
                zy_mu.append(hit[0])
                y_mu.append(hit[1])
            else:
                zy_e.append(hit[0])
                y_e.append(hit[1])
                
    px_mu = np.polyfit(zx_mu, x_mu, 1)
    chi_squared_x_mu = np.sum((np.polyval(px_mu, zx_mu) - x_mu) ** 2)
    
    py_mu = np.polyfit(zy_mu, y_mu, 1)
    chi_squared_y_mu = np.sum((np.polyval(py_mu, zy_mu) - y_mu) ** 2)
    
    px_e = np.polyfit(zx_e, x_e, 1)
    chi_squared_x_e = np.sum((np.polyval(px_e, zx_e) - x_e) ** 2)
    
    py_e = np.polyfit(zy_e, y_e, 1)
    chi_squared_y_e = np.sum((np.polyval(py_e, zy_e) - y_e) ** 2)
    
    return max(chi_squared_x_mu, chi_squared_y_mu, chi_squared_x_e, chi_squared_y_e)

# %%
# Main data load function
def readMUonE(minimal_number_of_hits=30, filter_chi2=True, filter_duplication=False):
    
    with open(events_file_path, mode='rb') as events_file:
        events = pickle.load(events_file)
        
        GNN_data = []
        
        for event_inex, event in enumerate(events):
            
            # Select events with at least 'minimal_number_of_hits' hits
            if len(event) < minimal_number_of_hits: continue
                
            # Select events with chi2 of linear fit of muone and electron small
            if filter_chi2 and check_ch2(event) > 0.02: continue
                
            X = np.empty((0, 4))
            for hit_index, hit in enumerate(event):
                # Select only muon and electron hits from event
                if hit[2] not in [1, 2]: continue
                    
                new_row = np.array([[hit[0],                # z
                                     hit[1],                # position
                                     z_to_layer(hit[0]),    # layer number
                                     hit[2]]])              # pid
    
                X = np.vstack([X, new_row])
        
            # Edge construction
            E = []
            for layer in np.arange(len(all_layers)):
                for i in np.argwhere(X[:, 2] == layer):
                    for j in np.argwhere(X[:, 2] == layer + 1):
                        E.append([i, j])
            E = np.array(E).T.squeeze()

            # Defining edge labels
            y_list = np.array([int(i[3] == j[3])*i[3] for i, j in zip(X[E[0]], X[E[1]])], dtype=int)
            Y = np.eye(3)[y_list].astype(int)
            
            # PID save
            PID = X[:,3]
            
            # Z scaling
            X = np.array([(X[:, 0] ) / z_scale, X[:, 1]]).T        # z, position
            
            event_data = Data(x = torch.from_numpy(X).float(),
                             edge_index = torch.from_numpy(E),
                             y = torch.from_numpy(Y),
                             pid = torch.from_numpy(PID))
            
            GNN_data.append(event_data)
        
        return GNN_data

# %%
GNN_data = readMUonE()

# Split data into training and test datasets
train_dataset, test_dataset = train_test_split(GNN_data, test_size=0.2, shuffle=True, random_state=42)

train_loader = DataLoader(train_dataset, batch_size=100, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

print(f'Negative Edges / Positive Edges = {train_dataset[0].y[:, 0].sum().item() / train_dataset[0].y[:, 1].sum().item():.2f}')
print(f'Size of training dataset: {len(train_dataset)} events')
print(f'Size of test dataset: {len(test_dataset)} events')
# Out:
# Negative Edges / Positive Edges = 2.00
# Size of training dataset: 88607 events
# Size of test dataset: 22152 events

# %% [markdown]
# #### Events plots

# %%
NUMBER_OF_EVENT_PLOTS = 10

def plot_event(event, print_data=False):
    
    if print_data:
        print("Event x:", event.x)
        print("Event edge_index:", event.edge_index)
        print("Event labels (y):", event.y)
        print("Event pid:", event.pid)
    
    plt.figure(figsize=(10, 5))
    
    x_coords = event.x[:, 0].numpy()
    y_coords = event.x[:, 1].numpy()
    edges = event.edge_index.numpy()
    labels = event.y
    pid = event.pid
    
    # Plot hits
    plt.scatter(x_coords[pid == 1], y_coords[pid == 1], c='m', label='Mion')
    plt.scatter(x_coords[pid == 2], y_coords[pid == 2], c='c', label='Elektron')
    
    negative_edge_indices = torch.nonzero(labels[:, 0] == 1).squeeze().numpy()
    muon_edge_indices = torch.nonzero(labels[:, 1] == 1).squeeze().numpy()
    electron_edge_indices = torch.nonzero(labels[:, 2] == 1).squeeze().numpy()
    
    # Plot negative edges
    plt.plot([x_coords[edges[0, negative_edge_indices[0]]], x_coords[edges[1, negative_edge_indices[0]]]],
             [y_coords[edges[0, negative_edge_indices[0]]], y_coords[edges[1, negative_edge_indices[0]]]],
             c='red', linewidth=1, label='Krawędź fałszywa')

    plt.plot([x_coords[edges[0, negative_edge_indices[1:]]], x_coords[edges[1, negative_edge_indices[1:]]]],
             [y_coords[edges[0, negative_edge_indices[1:]]], y_coords[edges[1, negative_edge_indices[1:]]]],
             c='red', linewidth=1)
    
    # Plot muon edges
    plt.plot([x_coords[edges[0, muon_edge_indices[0]]], x_coords[edges[1, muon_edge_indices[0]]]],
             [y_coords[edges[0, muon_edge_indices[0]]], y_coords[edges[1, muon_edge_indices[0]]]],
             c='m', linewidth=1, label='Krawędź prawdziwa (mion)')

    plt.plot([x_coords[edges[0, muon_edge_indices[1:]]], x_coords[edges[1, muon_edge_indices[1:]]]],
             [y_coords[edges[0, muon_edge_indices[1:]]], y_coords[edges[1, muon_edge_indices[1:]]]],
             c='m', linewidth=1)
    
    # Plot electron edges
    plt.plot([x_coords[edges[0, electron_edge_indices[0]]], x_coords[edges[1, electron_edge_indices[0]]]],
             [y_coords[edges[0, electron_edge_indices[0]]], y_coords[edges[1, electron_edge_indices[0]]]],
             c='c', linewidth=1, label='Krawędź prawdziwa (elektron)')

    plt.plot([x_coords[edges[0, electron_edge_indices[1:]]], x_coords[edges[1, electron_edge_indices[1:]]]],
             [y_coords[edges[0, electron_edge_indices[1:]]], y_coords[edges[1, electron_edge_indices[1:]]]],
             c='c', linewidth=1)
    
    # Plot x-z and y-z fits
    fit_data = {
        'mu_x': ([], []),
        'mu_y': ([], []),
        'e_x':  ([], []),
        'e_y':  ([], [])
    }

    def append_fit_data(hit, label):
        fit_data[label][0].append(hit[0].item())
        fit_data[label][1].append(hit[1].item())

    for pid_val, label_prefix in zip([1, 2], ['mu', 'e']):
        for hit in event.x[pid == pid_val]:
            layer = layer_type(z_scale * hit[0].item())
            if layer in ['x', 'y']:
                append_fit_data(hit, f"{label_prefix}_{layer}")

    styles = {
        'mu_x': ('m', '--', 'x-z Muon fit'),
        'mu_y': ('m', '-.', 'y-z Muon fit'),
        'e_x':  ('c', '--', 'x-z Electron fit'),
        'e_y':  ('c', '-.', 'y-z Electron fit')
    }

    for key, (color, linestyle, label) in styles.items():
        plt.plot(fit_data[key][0], fit_data[key][1], c=color, linewidth=1, linestyle=linestyle)
    
    plt.xlabel(r"$Z\ \left[10^3\ \mathrm{mm}\right]$")
    plt.ylabel(r"$X~/~Y~/~U~/~V\ \left[\mathrm{mm}\right]$")
    
    plt.legend()
    plt.show()

for i in range(NUMBER_OF_EVENT_PLOTS):
    plot_event(train_loader.dataset[i])

# %% [markdown]
# ### Model build

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
def train(model, train_loader, optimizer, weight):
    correct = 0
    total = 0
    total_loss = 0
    
    for batch in train_loader:
        optimizer.zero_grad()
        data = batch.to(device)
        pred = model(data)

        loss = F.cross_entropy(pred.float(), data.y.float())
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        correct += (pred.argmax(axis=1) == data.y.argmax(axis=1)).sum().item()
        total += len(pred)
        
    acc = correct / total
    return acc, total_loss


def evaluate(model, test_loader, weight):
    correct = 0
    total = 0
    total_loss = 0
    
    for batch in test_loader:
        data = batch.to(device)
        pred = model(data)
        loss = F.cross_entropy(pred.float(), data.y.float())
        total_loss += loss.item()
        correct += (pred.argmax(axis=1) == data.y.argmax(axis=1)).sum().item()
        total += len(pred)
        
    acc = correct / total
    return acc, total_loss

# %%
def make_mlp(
    input_size,
    sizes,
    hidden_activation='ReLU',
    output_activation='ReLU',
    layer_norm=False,
):
    '''Construct an MLP with specified fully-connected layers.'''
    hidden_activation = getattr(nn, hidden_activation)
    if output_activation is not None:
        output_activation = getattr(nn, output_activation)
        
    layers = []
    n_layers = len(sizes)
    sizes = [input_size] + sizes
    
    # Hidden layers
    for i in range(n_layers - 1):
        layers.append(nn.Linear(sizes[i], sizes[i + 1]))
        if layer_norm:
            layers.append(nn.LayerNorm(sizes[i + 1]))
        layers.append(hidden_activation())
        
    # Final layer
    layers.append(nn.Linear(sizes[-2], sizes[-1]))
    if output_activation is not None:
        if layer_norm:
            layers.append(nn.LayerNorm(sizes[-1]))
        layers.append(output_activation())
        
    return nn.Sequential(*layers)


class MPNN_Network(nn.Module):
    '''
    A message-passing graph network which takes a graph with:
    - bi-directional edges
    - node features, no edge features

    and applies the following modules:
    - a graph encoder (no message passing)
    - recurrent edge and node networks
    - an edge classifier
    '''

    def __init__(
        self,
        input_dim,
        hidden_node_dim,
        hidden_edge_dim,
        in_layers,
        node_layers,
        edge_layers,
        n_graph_iters=1,
        layer_norm=True,
    ):
        super(MPNN_Network, self).__init__()
        self.n_graph_iters = n_graph_iters

        # The node encoder transforms input node features to the hidden space
        self.node_encoder = make_mlp(input_dim, [hidden_node_dim] * in_layers)

        # The edge network computes new edge features from connected nodes
        self.edge_network = make_mlp(
            2 * hidden_node_dim, [hidden_edge_dim] * edge_layers, layer_norm=layer_norm
        )

        # The node network computes new node features
        self.node_network = make_mlp(
            hidden_node_dim + hidden_edge_dim,
            [hidden_node_dim] * node_layers,
            layer_norm=layer_norm,
        )

        # The edge classifier computes final edge scores
        self.edge_classifier = make_mlp(
            2 * hidden_node_dim, [hidden_edge_dim, 3], output_activation=None
        )

    def forward(self, data):
        # Make every edge bi-directional
        send_idx = torch.cat([data.edge_index[0], data.edge_index[1]], dim=0)
        recv_idx = torch.cat([data.edge_index[1], data.edge_index[0]], dim=0)

        # Encode the graph features into the hidden space
        x = self.node_encoder(data.x)

        # Loop over graph iterations
        for i in range(self.n_graph_iters):

            # Previous hidden state
            x0 = x

            # Compute new edge features
            edge_inputs = torch.cat([x[send_idx], x[recv_idx]], dim=1)
            e = self.edge_network(edge_inputs)

            # Sum edge features coming into each node
            aggr_messages = scatter_add(e, recv_idx, dim=0, dim_size=x.shape[0])

            # Compute new node features
            node_inputs = torch.cat([x, aggr_messages], dim=1)
            x = self.node_network(node_inputs)

            # Residual connection
            x = x + x0

        # Compute final edge scores; use original edge directions only
        start_idx, end_idx = data.edge_index
        clf_inputs = torch.cat([x[start_idx], x[end_idx]], dim=1)

        return self.edge_classifier(clf_inputs).squeeze(-1)

# %%
weight = 2.0

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
m_configs = {"input_dim": 2, "hidden_node_dim": 128, "hidden_edge_dim": 256, "in_layers": 2, "node_layers": 2, "edge_layers": 2, "n_graph_iters": 10, "layer_norm": True}
model = MPNN_Network(**m_configs).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.0004, weight_decay=1e-5, amsgrad=True)
# Out:
# /home/jupyter-dmizera/.local/lib/python3.9/site-packages/torch/cuda/__init__.py:611: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %% [markdown]
# ### Model learning

# %%
EPOCHS = 500

t_loss_v = []
t_acc_v = []
v_loss_v = []
v_acc_v = []
ep = 0

start_time = time.time()
epoch_times = []

for epoch in range(EPOCHS):
    ep += 1
    
    epoch_start_time = time.time()
    
    model.train()
    t_acc, t_total_loss = train(model, train_loader, optimizer, weight)
    t_loss_v.append(t_total_loss)
    t_acc_v.append(t_acc)

    model.eval()
    v_acc, v_total_loss = evaluate(model, test_loader, weight)
    v_loss_v.append(v_total_loss)
    v_acc_v.append(v_acc)

    epoch_end_time = time.time()
    epoch_times.append(epoch_end_time - epoch_start_time)
    avg_epoch_time = sum(epoch_times) / len(epoch_times)
    remaining_time = avg_epoch_time * (EPOCHS - (epoch + 1))
    remaining_minutes, remaining_seconds = divmod(remaining_time, 60)
    
    clear_output(wait=True)
    print(f'Epoch: {ep}, Loss: {v_total_loss:.4f}, Accuracy: {v_acc:.4f}, Time: {epoch_end_time - epoch_start_time:.2f}s, Avg. Time/Epoch: {avg_epoch_time:.2f}s, Remaining Time: {remaining_minutes:.0f}min:{remaining_seconds:.0f}s')
    
end_time = time.time()
total_training_time = end_time - start_time
total_minutes, total_seconds = divmod(total_training_time, 60)

print(f'Total Training Time: {total_minutes:.0f}min:{total_seconds:.0f}s')

loss, accuracy = evaluate(model, test_loader, weight)
print(f"Test loss: {loss:.3%}, Test accuracy: {accuracy:.3%}")
# Out:
# Epoch: 500, Loss: 101.5261, Accuracy: 0.9319, Time: 21.39s, Avg. Time/Epoch: 21.39s, Remaining Time: 0min:0s
# Total Training Time: 178min:14s
# Test loss: 93.188%, Test accuracy: 10152.612%

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(2, 2, constrained_layout=True, figsize=(10, 5))

data = [
    (np.arange(len(t_loss_v)), t_loss_v, "Funkcja kosztu (dane treningowe)"),
    (np.arange(len(t_acc_v)), t_acc_v, "Dokładność (dane treningowe)"),
    (np.arange(len(v_loss_v)), v_loss_v, "Funkcja kosztu (dane walidacyjne)"),
    (np.arange(len(v_acc_v)), v_acc_v, "Dokładność (dane walidacyjne)")
]

for ax, (x, y, title) in zip(axs.ravel(), data):
    ax.plot(x, y)
    ax.set_title(title)
    ax.set_xlabel("Epoka")
    ax.set_ylabel("Wartość")
    ax.set_yscale("linear")
    if "Dokładność" in title:
        ax.set_ylim(0, 1.05)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Model save / load

# %%
model_path = './model_2025_05_14-ternary.pth'

# Save the model state dictionary
# torch.save(model.state_dict(), model_path)
# print(f'Model saved to {model_path}')

# Load the model state dictionary
model.load_state_dict(torch.load(model_path))
print(f'Model loaded from {model_path}')
# Out:
# Model loaded from ./model_2025_05_14-ternary.pth

# %% [markdown]
# ### Model evaluation

# %% [markdown]
# #### Classified events plots

# %%
NUMBER_OF_CLASSIFIED_EVENT_PLOTS = 10
ERROR_ONLY = False
CUT = 0.5

def plot_classified_event(event, preds):
    
    plt.figure(figsize=(10, 5))
    
    x_coords = event.x[:, 0].numpy()
    y_coords = event.x[:, 1].numpy()
    edges = event.edge_index.numpy()
    labels = event.y
    pid = event.pid
    
    # Plot hits
    plt.scatter(x_coords[pid == 1], y_coords[pid == 1], c='m', label='Mion')
    plt.scatter(x_coords[pid == 2], y_coords[pid == 2], c='c', label='Elektron')
    
    # Plot classified edges
    predicted_classes = preds.argmax(axis=1)
    true_classes = labels.argmax(axis=1)
    
    for i in range(len(labels)):
        x_edge = [x_coords[edges[0, i]], x_coords[edges[1, i]]]
        y_edge = [y_coords[edges[0, i]], y_coords[edges[1, i]]]

        if predicted_classes[i] == 0 and true_classes[i] > 0:
            # False negatives
            plt.plot(x_edge, y_edge, '--', c='blue')
            
        elif predicted_classes[i] > 0 and true_classes[i] == 0:
            # False positives
            plt.plot(x_edge, y_edge, '--', c='red')
            
            # False positive – muon and electron scrambled
        elif (predicted_classes[i] == 1 and true_classes[i] == 2) \
                or (predicted_classes[i] == 2 and true_classes[i] == 1):
            plt.plot(x_edge, y_edge, ':', c='red')
            
        elif predicted_classes[i] == 1 and true_classes[i] == 1:
            # True positives – muon
            plt.plot(x_edge, y_edge, '-', c='m')
            
        elif predicted_classes[i] == 2 and true_classes[i] == 2:
            # True positives – electron
            plt.plot(x_edge, y_edge, '-', c='c')
            
#         elif predicted_classes[i] == 0 and true_classes[i] == 0:
#             # True negatives
#             plt.plot(x_edge, y_edge, '-', c='black')
    
    # Plot x-z and y-z fits
    fit_data = {
        'mu_x': ([], []),
        'mu_y': ([], []),
        'e_x':  ([], []),
        'e_y':  ([], [])
    }

    def append_fit_data(hit, label):
        fit_data[label][0].append(hit[0].item())
        fit_data[label][1].append(hit[1].item())

    for pid_val, label_prefix in zip([1, 2], ['mu', 'e']):
        for hit in event.x[pid == pid_val]:
            layer = layer_type(z_scale * hit[0].item())
            if layer in ['x', 'y']:
                append_fit_data(hit, f"{label_prefix}_{layer}")

    styles = {
        'mu_x': ('m', '--'),
        'mu_y': ('m', '-.'),
        'e_x':  ('c', '--'),
        'e_y':  ('c', '-.')
    }

    for key, (color, linestyle) in styles.items():
        plt.plot(fit_data[key][0], fit_data[key][1], c=color, linewidth=1, linestyle=linestyle)
    
    plt.xlabel(r"$Z\ \left[10^3\ \mathrm{mm}\right]$")
    plt.ylabel(r"$X~/~Y~/~U~/~V\ \left[\mathrm{mm}\right]$")
    
    plt.legend()
    plt.show()


# Plot a few events
events_plotted = 0
for i in range(len(test_loader.dataset)):
    event = test_loader.dataset[i].to(device)
    preds = torch.sigmoid(model(event)).to('cpu')

    if ERROR_ONLY:
        true_labels = event.y.cpu().argmax(dim=1)
        predicted_labels = preds.argmax(dim=1)
        if not torch.equal(true_labels, predicted_labels):
            plot_classified_event(event.to('cpu'), preds)
            events_plotted += 1
    else:
        plot_classified_event(event.to('cpu'), preds)
        events_plotted += 1
    
    if events_plotted >= NUMBER_OF_CLASSIFIED_EVENT_PLOTS:
        break

# %% [markdown]
# #### ROC curve and confusion matrix

# %%
y_test = []
y_pred_proba = []

# Batch processing to save VRAM
model.eval()

# Need to send data to GPU needed after laoding from disk
model.to(device)
for data in test_loader.dataset:
    data.to(device)

with torch.no_grad():
    for batch in test_loader:
        inputs = batch.to(device)
        labels = batch.y.to(device).argmax(dim=1)
        
        logits = model(inputs)
        
        probabilities = torch.nn.functional.softmax(logits, dim=1)
        
        y_pred_proba.append(probabilities.cpu())
        y_test.append(labels.cpu())

y_test = torch.cat(y_test).numpy()
y_pred_proba = torch.cat(y_pred_proba).numpy()

n_classes = y_pred_proba.shape[1]
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test == i, y_pred_proba[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

all_fpr = np.linspace(0, 1, 100)
mean_tpr = np.zeros_like(all_fpr)

for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= n_classes

plt.figure(figsize=(10, 8))

for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (area = {roc_auc[i]:.3f})')

plt.plot(all_fpr, mean_tpr, 'k--', label=f'Macro-average ROC (area = {auc(all_fpr, mean_tpr):.3f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

macro_auc = auc(all_fpr, mean_tpr)
print(f'Macro-averaged AUC: {macro_auc:.6f}')

y_pred = np.argmax(y_pred_proba, axis=1)
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title('Confusion Matrix')
plt.show()
# Out:
# Macro-averaged AUC: 0.987983

# %% [markdown]
# ### Track candidates evaluation

# %%
muon_error_counts = Counter()
electron_error_counts = Counter()

for i in range(len(test_loader.dataset)):
    event = test_loader.dataset[i].to(device)

    preds = torch.sigmoid(model(event)).to('cpu')
    pred_edge_types = torch.argmax(preds, dim=1).numpy()
    event = event.to('cpu')

    edges = event.edge_index.numpy()
    pid = event.pid

    incorrect_muon = 0
    incorrect_electron = 0

    # This loop checks types of edges connected to a given hit
    for hit in range(min(8, len(pid))):
        incoming_edges = np.where(edges[1] == hit)[0]
        outgoing_edges = np.where(edges[0] == hit)[0]
        
        related_edges = np.concatenate((incoming_edges, outgoing_edges))
        related_edge_types = pred_edge_types[related_edges]
        
        muon_edge_count = np.sum(related_edge_types == 1)
        electron_edge_count = np.sum(related_edge_types == 2)
        
        # When there is a draw in edge counts, probability is taken into account
        if muon_edge_count == electron_edge_count:
            muon_prob_sum = np.sum(preds[related_edges, 1].detach().numpy())
            electron_prob_sum = np.sum(preds[related_edges, 2].detach().numpy())
            hit_pid = 1 if muon_prob_sum > electron_prob_sum else 2
        else:
            hit_pid = 1 if muon_edge_count > electron_edge_count else 2
        
        expected_pid = pid[hit]

        if hit_pid != expected_pid:
            if expected_pid == 1:
                incorrect_muon += 1
            elif expected_pid == 2:
                incorrect_electron += 1


    # Counting incorrect hit types for current event
    muon_error_counts[incorrect_muon] += 1
    electron_error_counts[incorrect_electron] += 1


total_events = len(test_loader.dataset)

muon_table = [
    [error_count, event_count, f"{(event_count / total_events) * 100:.2f}%"]
    for error_count, event_count in sorted(muon_error_counts.items())
]

electron_table = [
    [error_count, event_count, f"{(event_count / total_events) * 100:.2f}%"]
    for error_count, event_count in sorted(electron_error_counts.items())
]

print(f"Muon error hits (Total # of events: {total_events})")
print(tabulate(muon_table, headers=["Error Hits", "# of Events", "%"], tablefmt="grid"))

print(f"\nElectron error hits (Total # of events: {total_events})")
print(tabulate(electron_table, headers=["Error Hits", "# of Events", "%"], tablefmt="grid"))
# Out:
# Muon error hits (Total # of events: 22152)
# +--------------+---------------+--------+
# |   Error Hits |   # of Events | %      |
# +==============+===============+========+
# |            0 |         18081 | 81.62% |
# +--------------+---------------+--------+
# |            1 |          1049 | 4.74%  |
# +--------------+---------------+--------+
# |            2 |          1562 | 7.05%  |
# +--------------+---------------+--------+
# |            3 |           233 | 1.05%  |
# +--------------+---------------+--------+
# |            4 |           239 | 1.08%  |
# +--------------+---------------+--------+
# |            5 |           231 | 1.04%  |
# +--------------+---------------+--------+
# |            6 |           757 | 3.42%  |
# +--------------+---------------+--------+
#
# Electron error hits (Total # of events: 22152)
# +--------------+---------------+--------+
# |   Error Hits |   # of Events | %      |
# +==============+===============+========+
# |            0 |         17936 | 80.97% |
# +--------------+---------------+--------+
# |            1 |          1093 | 4.93%  |
# +--------------+---------------+--------+
# |            2 |          1532 | 6.92%  |
# +--------------+---------------+--------+
# |            3 |           257 | 1.16%  |
# +--------------+---------------+--------+
# |            4 |           281 | 1.27%  |
# +--------------+---------------+--------+
# |            5 |           206 | 0.93%  |
# +--------------+---------------+--------+
# |            6 |           847 | 3.82%  |
# +--------------+---------------+--------+

# %% [markdown]
# #### Angle analysis

# %%
import numpy as np
import networkx as nx

def extract_hit_level_info(event, edge_probs, output=False):
    z = z_scale * event.x[:, 0].numpy()
    x = event.x[:, 1].numpy()
    edges = event.edge_index.numpy()
    pids  = event.pid.numpy()

    edge_probs = edge_probs.numpy()
    pred_cls   = edge_probs.argmax(axis=1)

    G = nx.Graph()
    for ei, c in enumerate(pred_cls):
        if c != 0:
            u, v = edges[:, ei]
            G.add_edge(u, v, ei=ei)

    comps = list(nx.connected_components(G))
    if len(comps) != 2:
        return None

    def slope(z1, z2, v1, v2):
        return float('inf') if z2 == z1 else (v2 - v1) / (z2 - z1)

    def delta_angle(z_vals, v_vals):
        m1 = slope(z_vals[0], z_vals[1], v_vals[0], v_vals[1])
        m2 = slope(z_vals[2], z_vals[3], v_vals[2], v_vals[3])
        return (np.arctan(m1) - np.arctan(m2)) * 1000.0  # mrad

    hit_out = []

    for comp in comps:
        hits = list(comp)

        zx, xx, zy, yy = [], [], [], []
        for h in hits:
            if layer_type(z[h]) == 'x':
                zx.append(z[h]);  xx.append(x[h])
            else:
                zy.append(z[h]);  yy.append(x[h])

        if len(zx) < 4 or len(zy) < 4:
            return None

        ang_x = delta_angle(10*np.array(zx[:4]), xx[:4])
        ang_y = delta_angle(10*np.array(zy[:4]), yy[:4])

        for h in hits:
            inc = np.where(edges[1] == h)[0]
            out = np.where(edges[0] == h)[0]
            rel = np.concatenate((inc, out))
            if len(rel) == 0:
                continue

            true_pid = int(pids[h])
            if true_pid == 1:                      # muon
                prob_diff = float(edge_probs[rel, 2].mean())  # probability(electron)
            elif true_pid == 2:                    # electron
                prob_diff = float(edge_probs[rel, 1].mean())  # probability(muon)
            else:
                continue

            hit_out.append({
                "hit_id":        int(h),
                "true_pid":      true_pid,
                "angle_x_mrad":  float(ang_x),
                "angle_y_mrad":  float(ang_y),
                "prob_diff_class": prob_diff
            })

    if output:
        print(f"zwrócono {len(hit_out)} hitów")
    return hit_out

# %%
all_hits_data = []

for event in tqdm(test_loader.dataset, desc="Przetwarzanie eventów"):
    event_gpu = event.to(device)

    with torch.no_grad():
        edge_logits = model(event_gpu)
        edge_probs  = torch.sigmoid(edge_logits).cpu()

    event_cpu = event_gpu.cpu()
    hit_info  = extract_hit_level_info(event_cpu, edge_probs, output=False)

    if hit_info is not None:
        all_hits_data.extend(hit_info)

print(f"\nZebrano dane dla {len(all_hits_data)} hitów z "
      f"{len(all_hits_data)//len(event_cpu.x)} eventów (przybliżenie).")

df_hits = pd.DataFrame(all_hits_data)
# Out:
# Przetwarzanie eventów: 100%|██████████| 22152/22152 [01:34<00:00, 233.36it/s]
# Zebrano dane dla 513735 hitów z 21405 eventów (przybliżenie).

# %%
def plot_combined_histogram(ax, df, pid_val, particle_name):
    angle_bins = [(0.000, 0.005), (0.005, 0.010), (0.010, 0.015)]
    styles = ['b', 'g', 'r']

    df = df.copy()
    df['abs_angle'] = df[['angle_x_mrad', 'angle_y_mrad']].abs().min(axis=1)

    for (low, high), style in zip(angle_bins, styles):
        mask = (
            (df['true_pid'] == pid_val) &
            (df['abs_angle'] >= low) &
            (df['abs_angle'] <  high)
        )
        data = df.loc[mask, 'prob_diff_class']
        if data.empty:
            continue
        label = f"{10*low:.2f}–{10*high:.2f} mrad"
        ax.hist(data, bins=30, histtype='step',
                density=True, linewidth=1.5,
                color=style, label=label)

    
    if particle_name == 'Elektron':
        ax.set_title("Rzeczywiste elektrony")
        ax.set_xlabel("Prawdopodobieństwo klasyfikacji jako mion")
    else:
        ax.set_title("Rzeczywiste miony")
        ax.set_xlabel("Prawdopodobieństwo klasyfikacji jako elektron")
    ax.set_ylabel("Częstość wystąpień [log]")
    ax.grid(True)
    ax.legend()
    ax.set_yscale('log')
    ax.set_xlim([0, 1])

fig, axes = plt.subplots(1, 2, figsize=(12, 4), sharey=True)

plot_combined_histogram(axes[0], df_hits, pid_val=2, particle_name="Elektron")
plot_combined_histogram(axes[1], df_hits, pid_val=1, particle_name="Mion")

plt.tight_layout()
plt.show()
